# %% [markdown]
# # from IPython.display import display, HTML, Javascript
#
# def f():
#     return HTML("""
#     <style>
#         @font-face {
#             /* تعریف نام فونت */
#             font-family: 'BZar';
#             /* اکسپلورر 9 به بعد */
#             src: url('font/BZar.eot');
#             /* بررسی نصب بودن فونت در سیستم کاربر */
#             src: local('bZar'),
#                  /* برای برخی از مرورگرها مانند سافاری */
#                  local('b Zar'),
#                  /* هک برای اکسپلورر 8 و ماقبل */
#                  url('font/BZar.eot?#iefix') format('embedded-opentype'),
#                  /* فرمت مناسب مرورگرهای خیلی جدید */
#                  url('font/BZar.woff2') format('woff2'),
#                  /* فرمت مناسب مرورگرهای تقریبا جدید */
#                  url('font/BZar.woff') format('woff'),
#                  /* تمام مرورگرها به جزء اکسپلورر */
#                  url('fonts/BZar.ttf') format('truetype'),
#                  /* نسخه های قدیمی سیستم عامل iOS */
#                  url('font/BZar.svg#BZar') format('svg');
#             font-style: normal;
#             font-weight: normal;
#             font-display: swap;
#         }
#
#
#         .reveal .slides {
#             direction: rtl;
#             text-align: right;
#         }
#
#         div {
#             direction: ltr;
#             text-align: left;
#         }
#
#         p > img {
#           display: block;
#           margin-left: auto;
#           margin-right: auto;
#           max-width:75%;
#           height:auto;
#         }
#
#         div.text_cell_render.rendered_html > *, li > p, .rendered_html p, #quarto-document-content > *
#         {
#             direction: rtl;
#             text-align: right;
#             font-family: BZar, Tahoma, Geneva, sans-serif;
#             font-size: x-large;
#             line-height: 26pt;
#         }
#
#         .jp-CodeMirrorEditor .jp-Editor .jp-InputArea-editor {
#             direction: rtl !important;
#         }
#
#         .CodeMirror-lines .output_subarea .output_text .output_stream .output_stdout{
#             direction: ltr !important;
#         }
#     </style>
#     """)
#
# f()

# %%
from IPython.display import display, HTML, Javascript

def g():
    return HTML("""
    <link rel="stylesheet" href="css/jquery.jqZoom.css" />
    <script src="js/jquery-1.12.4.min.js"></script>
    <script src="js/jquery.zoom.min.js"></script>
    <script>
        $(document).ready(function(){
            $("img").children().off();
            $('img')
            .wrap('<span style="display:inline-block"></span>')
            .css('display', 'block')
            .parent()
            .zoom({ on:'grab', duration: 150, magnify: 1 });
        });
    </script>
    """)

g()
# Out:
#     <link rel="stylesheet" href="css/jquery.jqZoom.css" />
#     <script src="js/jquery-1.12.4.min.js"></script>
#     <script src="js/jquery.zoom.min.js"></script>
#     <script>
#         $(document).ready(function(){
#             $("img").children().off();
#             $('img')
#             .wrap('<span style="display:inline-block"></span>')
#             .css('display', 'block')
#             .parent()
#             .zoom({ on:'grab', duration: 150, magnify: 1 });
#         });
#     </script>

# %% [raw]
# ---
# title: "فصل اول"
# format:
#   docx:
#     toc: true
#     section-numbers: true
#     highlight-style: github
#     dir: rtl
# #  pptx:
# #    toc: true
# #    execute:
# #      echo: false
# #      warning: false
#   html:
#     css: css/style.css
#     code-fold: true
#     echo: true
#     self-contained: false
#     lang: fa
# #  revealjs:
# #    incremental: true
# #    dir: rtl
# #  pdf:
# #    number-sections: true
# #    colorlinks: true
# #    pdf-engine: xelatex
# #    keep-tex: true
# page-layout: article
# toc: false
# dir: rtl
# lang: fa
# jupyter: python3
# ---

# %% [markdown]
# به نام خدا
#
# -  یادگیری عمیق چیست؟
#
# ## مطالب فصل
# -  مفاهیم پایه
# -  نحوه توسعه یادگیری ماشین
# -  عوامل محبوبیت  یادگیری عمیق و آینده آن
#
# ## مقدمه
#    - هوش مصنوعی در ۱۹۵۰ متولد شد.
#    - امروزه هوش مصنوعی کاربردهای متنوعی دارد:
#       * ربات‌های گفتگو محور
#       * خودروهای خودران
#       * دستیار‌های مجازی
#
#
# ![ارتباط هوش مصنوعی، یادگیری ماشین و یادگیری عمیق](img/01-01.png)
#
# ## تعریف هوش مصنوعی
# -  تلاشی برای خودکار سازی فعالیت‌های هوشمندانه‌ای که در حالت عادی توسط انسان انجام می‌شود.
#
# ## تاریخچه
# -  از ۱۹۵۰ تا ۱۹۸۰ نوعی از هوش مصنوعی در جریان بود که بیشتر با قوانین زیاد و دستی مسائل را حل می‌کرد مانند مسئله شطرنج.
# -  این نوع از یادگیری تحت عنوان یادگیری نمادین نامیده می‌شد که نهایت آن سیستمهای خبره (Expert Systems) بود.
# -  ولی بعد از آن یادگیری ماشین متولد شد.
#
# -  مفهوم یادگیری ماشین به ۱۸۴۳ برمیگردد.
# -  ماشین‌ها فقط آنچه ما یاد داریم را انجام می‌دهند.
# -  اما خلاقیت، یادگیری بر اساس تجربه و فکر کردن چطور؟.
#
# ## تز تورینگ
# -  در ۱۹۵۰ دکتر تورینگ تست تورینگ ارائه کرد.
#
# ## ایده یادگیری ماشین چیست؟
# -  در یادگیری ماشین به ورودی و خروجی نگاه می‌کنیم و قوانین بین آنها را استخراج می‌کنیم.
# -  در یادگیری ماشین ، ماشین آموزش داده می‌شود ولی برنامه ریزی نمی‌شود.
# -  یادگیری ماشین یک پارادایم جدید برنامه‌نویسی است.
#
# ![Machine learning: a new programming paradigm](img/01-02.png)
#
#
# ## پیشرفت یادگیری ماشین
# -  در ۱۹۹۰ یادگیری ماشین یک ترند شد.
# 	- افزایش قدرت سخت افزار
# 	- وجود مجموعه داده‌های بزرگ
#
# ## تفاوت بین یادگیری ماشین و آمار
# -  شبیه تفاوت شیمی و پزشکی است.
# -  در یادگیری ماشین ما با مجموعه داده‌های بزرگ و پیچیده سر و کار داریم.
# -  بیشتر یک رویکرد مهندسی مورد نظر است تا ریاضی و فیزیک.
#
# ## در یادگیری ماشین سه چیز نیاز داریم
# 1. داده‌های ورودی
# 2. نمونه‌هایی از خروجی مورد انتظار
# 3. میزان خوب بودن الگوریتم به عنوان یک سیگنال بازخورد برای **تنظیم** الگوریتم
#    * به این تنظیم  یادگیری می‌گوییم.
#
# ## بازنمایی داده‌ها
# -  پس در واقع یادگیری به معنای تبدیل با معنا (بازنمایی) داده هاست به نحوی که ورودی به خروجی نزدیک شود.
# -  برای مثال تشخیص ستاره و دایره به عنوان مسئله ورودی داده می‌شود.
#
# ![Some sample data](img/01-03.png)
#
# -  درصد صحت نتیجه به عنوان معیار و سیگنال و تنظیم استفاده می‌شود.
# -  راه حل پیشنهادی برای حل این مسئله در دوران صفحه مختصات خواهد بود.
#
# ![Coordinate change](img/01-04.png)
#
# -  این راه حل در واقع باز نمایی ورودی برای نزدیک شدن به خروجی مطلوب است.
# - اما همیشه این بازنمایی ساده نیست (مثلاً تشخیص دست نوشته به صورت خودکار).
#
# ## فضای فرضیه
# -  الگوریتم‌های یادگیری ماشین در یک فضای محدود به دنبال تبدیل بهینه هستند به این فضا ، فضای فرضیه می‌گوییم.
#
# ## یادگیری عمیق
# -  به تعدادی از لایه‌های متوالی اشاره دارد که تلاش می‌کنند در هرمرحله نمایش یا تبدیل بامعنا تری از داده‌های اولیه پیدا کنند.
# -  نام‌های دیگر یادگیری عمیق عبارتند از:.
# 	-  یادگیری بازنمایی‌های لایه ای.
# 	-  یادگیری بازنمایی‌های سلسله مراتبی.
#
# ## یادگیری کم عمق
# -  یادگیری‌های قبلی مبتنی بر شبکه عصبی خیلی عمیق نبودند (حدوداً دو لایه).
# -  به همین دلیل کم عمق یا shallow  خوانده می‌شدند.
#
# ## زیست شناسی و یادگیری عمیق
# -  ارتباط بین زیست شناسی و یادگیری عمیق یعنی شبکه عصبی یک داستان قدیمی و نادرست است.
#
# ## مثالی از تشخیص رقم
# ![A deep neural network for digit classification](img/01-05.png)
#
# ![Data representations learned by a digit-classification model](img/01-06.png)
#
# ## مفهوم یادگیری در «یادگیری عمیق»
# -  شبکه عمیق تعدادی لایه دارد که در هر لایه ورودی‌ها در پارامتر‌هایی که همان وزن‌های آن لایه باشند ضرب می‌شوند.
# -  در این جا یادگیری به معنای یافتن مقدار مناسب این وزن‌ها می‌باشد.
# -  اما تعداد این وزن‌ها بسیار زیاد است و تغییر یکی باعث تأثیر بر مقدار همه می‌شود.
# -  در واقع وزنها پارامترهای شبکه عصبی عمیق هستند.
#
#
# ## سیگنال بازخورد
# -  سیگنال بازخورد در واقع همان تابع خطاست.
# -  از آن برای تنظیم وزن‌ها استفاده می‌شود.
# -  نام‌های دیگر آن عبارتند از:
# 	- loss function.
# 	- objective function.
# 	- cost function.
#
# ## معماری کلی الگوریتم یادگیری عمیق
# -  معماری کلی یک الگوریتم یادگیری عمیق به شکل زیر است.
#
# ![How deep learning works](img/01-09.png)
#
# ## الگوریتم پس‌انتشار
# -  الگوریتم اصلی مورد استفاده در یادگیری عمیق در قالب یک بهینه ساز پیاده‌سازی می‌شود تحت عنوان backpropagation  یا پس  انتشار خوانده می‌شوند.
#
# ## دستاوردها
# -  برخی از نتایج و دستاوردهای یادگیری عمیق از ۲۰۱۰ به بعد.
#    -  قدرت دسته بندی تصاویر نزدیک به دقت انسان.
#    -  ایجاد زیرنویس از روی صدای فیلم.
#    -  تبدیل دست نوشته به متن.
#    -  بهبود قابل توجه در ترجمه ماشینی.
#    -  تبدیل متن به گفتار TTS.
#    -  کارهای هنری.
# -  البته هنوز در زمینه مکالمه‌های در حد انسان و ترجمه همه زبانها در حد انسان خیلی پیشرفت  نشده است.
#
# ## زمستان‌های هوش مصنوعی
# -  باید مواظب باشیم که بیش از حد از هوش مصنوعی و یادگیری عمیق انتظار نداشته باشیم.
# -  تا به حال هوش مصنوعی دو زمستان حمایت‌های مالی را در سالهای ۱۹۶۰ و ۱۹۸۰ تجربه کرده است!.
# -  باید مواظب زمستان سوم باشیم.
# -  در واقع امید واری‌های کوتاه مدت را نباید باور کنیم ولی در دراز مدت به هوش مصنوعی می‌تواند نقش مهمی در زندگی داشته باشد.
# -  یادگیری عمیق همه یادگیری ماشین نیست گاهی داده‌های کافی برای آموزش با یادگیری عمیق نداریم گاهی سایر الگوریتم‌ها بهتر هستند.
#
# ## برخی روش‌های یادگیری ماشین
# 1. مدل‌سازی احتمالاتی
# 2. شبکه‌های عصبی اولیه
# 3. روش‌های مبتنی بر کرنل
# 4. روش‌های مبتنی بر درخت
# 5. شبکه‌های عمیق
#
#
# ## ۱- مدل سازی احتمالاتی
# این روش مبتنی بر آمار است مانند
# -  الگوریتم بیز که در قرن ۱۸ پیشنهاد شده است.
# -  نمونه دیگر رگرسیون لجستیک است که البته یک الگوریتم دسته بندی است!.
# 	- به عنوان Hello world  در یادگیری ماشین پیشنهاد می‌شود.
#
# ## ۲- شبکه‌های عصبی اولیه
# -   در ۱۹۵۰ این ایده وجود داشت ولی در ۱۹۸۰ ایده الگوریتم پس انتشار باعث گسترش استفاده از آنها شد.
# -   اولین استفاده در سال ۱۹۸۹ توسط یان لکان در LeNet رخ داد که برای تشخیص ارقام روی بسته‌های پستی در پست ایالات متحده استفاده می‌شد.
#
# ## ۳- روشهای مبتنی بر کرنل
# -  معروف ترین این روش‌ها SVM  یا ماشین بردار پشتیبان است.
# -  در این روش مرز بین دو دسته پیدا می‌شود.
# -  اول داده‌ها به فضای با ابعاد بالاتر می‌روند تا بتوان آنها را با یک خط یا یک ابر صفحه جدا کرد.
# -  سپس این ابرصفحه مناسب که حداکثر فاصله را تا نزدیک ترین نقاط دارد پیدا می‌شود.
#
# ![A decision boundary](img/01-10.png)
#
# ## kernel trick
# -  در گام اول SVM معمولا از kernel trick  استفاده می‌شود تا بتوان بدون تبدیل نقاط اولیه فاصله آنها را در فضای مقصد با ابعاد بالا و به صورت کارآمد به دست آورد.
#
# ## ویژگی‌های روش ماشین بردار پشتیبان
# -  روش ماشین بردار پشتیبان تئوری قوی دارد.
# -  قابلیت تفسیر خوبی هم دارد.
# -  اما در مورد داده‌های حجیم و پیچیده مانند تصویر خوب کار نمی‌کند.
# -  نیازمند عملیات سخت مهندسی ویژگی (Feature Engineering)  است.
#
# ## ۴- روش‌های مبتنی بر درخت و جنگل و ماشین‌های Gradient Boosting
# -  روش‌های مبتنی بر درخت شبیه فلوچارت عمل می‌کنند.
# -    روش‌های جنگل تصادفی از تجمیع Ensemble  تعداد زیادی درخت به دست می‌آیند.
# -    معمولاً در مسابقات در بین روشهای غیر عمیق رتبه دوم را داشتند.
# -  در سال ۲۰۱۴ روش‌های GB  پیشنهاد شد که نقاط ضعف مدل قبلی را به نوعی پوشش می‌دادند.
# -  معمولاً GB  بهتر است جنگل تصادفی عمل می‌کند و جزو بهترین روشها در مسابقات محسوب می‌شود.
#
# ![A decision tree](img/01-11.png)
#
# ## ۵- شبکه‌های عمیق
# -   در مسابقه موسوم به ImageNet  گروه آقای Hinton   توانستند بهترین نتیجه قبلی را از74.3 ٪ به 83.6 ٪   برساند
# -  بعداً در سال ۲۰۱۵ دقت به 96.4 ٪  رسید و مسئله حل شد
# -  بعدها یادگیری عمیق کاربرد گسترده ای یافت.
# 	- مثلاً در شتاب دهنده CERN  از Keras  استفاده می‌شود.
#
#
#
# ## چرا یادگیری عمیق متفاوت است
# -  در یادگیری عمیق نیاز به مهندسی ویژگی نیست.
# -  به دقت بالاتر به روش ساده تری می‌رسیم.
# -  متاسفانه نمی‌توانیم روشهای غیر هم این را پشت هم قرار دهیم.
# 	- یادگیری عمیق از روی داده‌ها شامل یادگیری لایه ای و همزمان و هماهنگ همه لایه‌ها با هم است.
#
# ## ابزارهای مورد استفاده در یادگیری ماشین مدرن
# -  در بین برندگان مسابقات کگل که در سال‌های بین ۲۰۱۷ تا ۲۰۱۹  رتبه‌های اول تا سوم را به دست آورده بودند.
# -  بیشترین ابزار‌ها Keras  برای مجموعه داده‌های حسی مانند تصویر بودند.
# -  روشهای GB  برای داده‌های ساخت یافته بودند.
# 	- scikit-learn.
# 	- LightGBM.
# 	- XGBoost.
#
# ![Machine learning tools used by top teams on Kaggle](img/01-12.png)
#
# ![Tool usage across the machine learning and data science industry](img/01-13.png)
#
# ## چرا یادگیری عمیق دیر پرواز کرد؟
# 1.   سخت افزار
# 2.   مجموعه داده‌های معیار benchmarks
# 3.   پیشرفتهای الگوریتمی برای بهینه‌سازی
# -  در واقع سخت افزار و داده‌ها بعد از GPU و Internet  مهیا شدند.
# -  امروزه حتی می‌توانیم ازTPU  کمک بگیریم.
# -  مثلاً ۱۰۲۴ tpu  معادل ۱۰ درصد ابر کامپیوتر آی بی ام در سال ۲۰۲۰ است که به آن یک پاد Pod می‌گوییم.
# -  اگر هوش مصنوعی را به عنوان انقلاب صنعتی جدید بشناسیم یادگیری عمیق بخار موتور این انقلاب است و داده‌ها زغال این موتور محسوب می‌شوند.
#
# ## محو سیگنال بازخورد
# -  در الگوریتم‌های یادگیری قدیمی سیگنال بازخورد بعد از تعدادی لایه محو می‌شد.
# 	- برای حل این مشکل در یادگیری عمیق از.
# 	- 	توابع فعال ساز بهتر ،.
# 	- 	مقدار دهی اولیه وزن‌ها ،.
# 	- 	روش‌های بهتر بهینه سازی استفاده شد.
# -  بعدها Batch Normalization و Residual Connection و ...  به عمیق تر شدن لایه‌ها کمک کرد.
#
# ## نمودار سرمایه گذاری روی هوش مصنوعی
#
# ![سرمایه‌گذاری در هوش مصنوعی](img/01-14.png)
#
# ## سه ویژگی مهم یادگیری عمیق که باعث ماندگاری آن می‌شود
# 1. سادگی که به دلیل حذف مهندسی ویژگی و سیستم End2End  است.
# 2. توسعه پذیری یعنی می‌توانیم یک مسئله را روی تعداد زیادی GPU‌ و TPU  قرار دهیم.
# 3. همه گیری و قابلیت استفاده مجدد:
# 	- یعنی می‌توانیم از شبکه‌هایی که از قبل آموزش دیده اند استفاده کنیم.
# 	- همچنین نیازی به بازآموزی شبکه از اول در حین کار وجود ندارد (امکان Online Learning)
